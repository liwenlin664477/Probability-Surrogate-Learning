# %%
from pdf2image import convert_from_path

pdf_path = "__figs__/errors_burgers_IFHoGP.pdf"

# Convert the PDF to images
images = convert_from_path(pdf_path)

# Save the first page of the PDF as a PNG
images[0].save("__figs__/errors_burgers_IFHoGP.png", 'PNG')

# %%
from IPython.display import Image, display
display(Image(filename='__figs__/errors_burgers_IFHoGP.png'))

# %%
from pdf2image import convert_from_path

pdf_path = "__figs__/errors_heat_IFHoGP.pdf"

# Convert the PDF to images
images = convert_from_path(pdf_path)

# Save the first page of the PDF as a PNG
images[0].save("__figs__/errors_heat_IFHoGP.png", 'PNG')

# %%
from IPython.display import Image, display
display(Image(filename='__figs__/errors_heat_IFHoGP.png'))

# %%
from pdf2image import convert_from_path

pdf_path = "__figs__/errors_poisson_IFHoGP.pdf"

# Convert the PDF to images
images = convert_from_path(pdf_path)

# Save the first page of the PDF as a PNG
images[0].save("__figs__/errors_poisson_IFHoGP.png", 'PNG')

# %%
from IPython.display import Image, display
display(Image(filename='__figs__/errors_heat_IFHoGP.png'))
