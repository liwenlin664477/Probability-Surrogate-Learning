# %%
import numpy as np
import os
import torch
import torch.distributions as distributions
from torch.optim import Adam
from torch.optim import LBFGS
import tensorly as tl
from torch.autograd import Variable
from sklearn.cluster import KMeans
# from kernels import KernelRBF
# from kernels import KernelARD
from sklearn import metrics
from scipy.io import loadmat
import random

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
torch.set_default_tensor_type(torch.DoubleTensor)
tl.set_backend('pytorch')

#using ard kernel for the actual input
size = int(10000 / 5 + 1)
epochs = np.ones(size)
test_rmse = np.ones(size)
test_nrmse = np.ones(size)
test_mae = np.ones(size)
test_nmae = np.ones(size)

class KernelRBF:
    def __init__(self, jitter):
        self.jitter = jitter
        
    def matrix(self, X, ls):
        K = self.cross(X, X, ls)
        Ijit = self.jitter*torch.eye(X.shape[0]).to(K.device)
        K = K + Ijit
        return K
        
        
    def cross(self, X1, X2, ls):
        norm1 = torch.reshape(torch.sum(torch.square(X1), dim=1), [-1,1])
        norm2 = torch.reshape(torch.sum(torch.square(X2), dim=1), [1,-1])
        K = norm1 - 2.0*torch.matmul(X1,X2.T) + norm2
        K = torch.exp(-1.0*K/ls)
        return K
    
class KernelARD:
    def __init__(self, jitter):
        self.jitter = jitter
        
    def matrix(self, X, ls):
        K = self.cross(X, X, ls)
        Ijit = self.jitter*torch.eye(X.shape[0]).to(K.device)
        K = K + Ijit
        return K
        
        
    def cross(self, X1, X2, ls):
        ls_sqrt = torch.sqrt(ls)
        X1 = X1/ls_sqrt
        X2 = X2/ls_sqrt
        norm1 = torch.reshape(torch.sum(torch.square(X1), dim=1), [-1,1])
        norm2 = torch.reshape(torch.sum(torch.square(X2), dim=1), [1,-1])
        K = norm1-2.0*torch.matmul(X1,X2.T) + norm2
        #K = amp*torch.exp(-1.0*K)
        K = torch.exp(-1.0*K)
        return K


class HoGPR:
    #X: training data, N x s
    #Y: training output tensor, N x d_1 x ... x d_K
    #R: dimension of latent features per output mode
    #device: cpu or gpu
    def __init__(self, X, Y, R, device, jitter=1e-3):
        self.device = device
        self.X = torch.tensor(X, device=self.device, requires_grad=False)
        self.Y = torch.tensor(Y, device=self.device, requires_grad=False)
        self.N = X.shape[0]
        self.nout_mode = self.Y.ndim - 1
        self.jitter = jitter
        #features per mode 
        self.V = [self.X] 
        #latent features per output mode
        for m in range(self.nout_mode):
            self.V.append(torch.randn(self.Y.shape[m+1], R, requires_grad=True))
        self.log_ls = [torch.tensor(np.zeros(self.V[m].shape[1]), device=self.device, requires_grad=True) for m in range(len(self.V))]
        self.kernel = [KernelARD(self.jitter) for m in range(len(self.V))]
        self.log_tau = torch.tensor(0.0, device=self.device, requires_grad=True)
        #hack an awkard property
        self.Y_mean = None
        self.Y_std = None
        self.i = 0


    def neg_ll_surrogate(self):
        noise_var = torch.exp(-self.log_tau)
        #kernel matrices
        Kmat = [self.kernel[m].matrix(self.V[m], torch.exp(self.log_ls[m])) for m in range(len(self.V))]
        Eigenvals = [torch.linalg.eigvalsh(Kmat[m]).reshape([-1, 1]) for m in range(len(self.V))]
        A = tl.cp_tensor.cp_to_tensor((torch.ones(1), Eigenvals)) + noise_var
        log_detK = torch.sum(torch.log(A))
        with torch.no_grad():
            U = []
            Ut = []
            for m in range(len(self.V)):
                damb, eigvecs = torch.linalg.eigh(Kmat[m])
                U.append(eigvecs.real)
                Ut.append(eigvecs.real.T)
            A1 = tl.tenalg.multi_mode_dot(self.Y, Ut)
            A1 = A1/A
            G = tl.tenalg.multi_mode_dot(A1, U)
        A2 = tl.tenalg.multi_mode_dot(G, Kmat) + noise_var*G
        neg_ll_surr = 0.5*log_detK - 0.5*torch.sum(A2*G)
        return neg_ll_surr
        
    def pred(self, Xte):
        with torch.no_grad():
            cross_klist = [self.kernel[0].cross(Xte, self.X, torch.exp(self.log_ls[0]))]
            Kmat = [self.kernel[m].matrix(self.V[m], torch.exp(self.log_ls[m])) for m in range(len(self.V))]
            U = []
            Ut = []
            Lam = []
            for m in range(self.nout_mode):
                cross_klist.append(Kmat[m+1]) 
            for m in range(len(self.V)):
                eigvals, eigvecs = torch.linalg.eigh(Kmat[m])
                U.append(eigvecs.real)
                Ut.append(eigvecs.real.T)
                Lam.append(eigvals.real.reshape([-1,1]))
                
            noise_var = torch.exp(-self.log_tau)
            A = tl.cp_tensor.cp_to_tensor((torch.ones(1), Lam)) + noise_var
            A1 = tl.tenalg.multi_mode_dot(self.Y, Ut)
            A1 = A1/A
            G = tl.tenalg.multi_mode_dot(A1, U)
            pred_mean = tl.tenalg.multi_mode_dot(G, cross_klist)
            return pred_mean

    #using Matheron's rule to gnerate M independent posterior sample; X_star can be multiple inputs
    def posterior_samples(self, X_star, M):
        X_aug = torch.cat((self.X, X_star), dim=0)
        K0 = self.kernel[0].matrix(X_aug, torch.exp(self.log_ls[0]))
        Kmat = [self.kernel[m].matrix(self.V[m], torch.exp(self.log_ls[m])) for m in range(1, len(self.V))]
        Kmat = [K0] + Kmat
        #generate prior samples first
        Chols = [torch.linalg.cholesky(Kmat[m]) for m in range(len(self.V))]
        nvec = [Kmat[m].shape[0] for m in range(len(self.V))] #(N + N*) x d1 x ... x dK
        Noise = torch.normal(0.0, 1.0, size=[M] + nvec) #M x (N+N*) x d1 x ... x dK 
        #M x (N+N*) x d1 x ... x dK
        F = tl.tenalg.multi_mode_dot(Noise, Chols, modes=[j for j in range(1,len(self.V)+1)] )
        #M x N x d1 x ... x dK
        nvec[0] = self.N
        F1 = F[:, 0:self.N] + torch.normal(0.0, 1.0, size=[M] + nvec)
        F2 = F[:, self.N:] #M x N* x d1 x ... x dK
        Ydiff = self.Y - F1 #M x N x d1 x ... x dK
        #we do not need the following for gradient tracking
        with torch.no_grad():
            Kmat[0] = K0[0:self.N, 0:self.N]
            U = []
            Ut = []
            Lam = []
            for m in range(len(self.V)):
                    eigvals, eigvecs = torch.linalg.eigh(Kmat[m])
                    U.append(eigvecs.real)
                    Ut.append(eigvecs.real.T)
                    Lam.append(eigvals.real.reshape([-1,1]))
            noise_var = torch.exp(-self.log_tau)
            A = tl.cp_tensor.cp_to_tensor((torch.ones(1), Lam)) + noise_var #N x d1 x ... x dK
            A1 = tl.tenalg.multi_mode_dot(Ydiff, Ut, modes=[j for j in range(1, len(self.V)+1)])
            A1 = A1/A #M x N x d1 x ... x dK
            G = tl.tenalg.multi_mode_dot(A1, U, modes=[j for j in range(1, len(self.V)+1)])
        Kmat[0] = K0[self.N:, 0:self.N]
        post_samples = tl.tenalg.multi_mode_dot(G, Kmat, modes=[j for j in range(1, len(self.V)+1)]) + F2
        return post_samples #M x N* x d1 x .... x dK
        
        
            
    def train(self, Xte, Yte, lr, max_epochs=100):
        Xte = torch.tensor(Xte, device=self.device)
        Yte = torch.tensor(Yte, device=self.device)
        paras = self.V[1:] + self.log_ls + [self.log_tau]
        
        minimizer = Adam(paras, lr=lr)
        for epoch in range(max_epochs):
            minimizer.zero_grad()
            loss = self.neg_ll_surrogate()
            loss.backward(retain_graph=True)
            minimizer.step()
            if epoch%5 == 0:
                self._callback(Xte, Yte, epoch)
                
        self._callback(Xte, Yte, max_epochs)

    def _callback(self, Xte, Yte, epoch):
        with torch.no_grad():
            pred_tr = self.pred(self.X)
            err_tr = torch.sqrt(torch.mean(torch.square(pred_tr - self.Y)))
            pred_te = self.pred(Xte)
            if False and epoch%20 == 0:
                pred_samples = self.posterior_samples(Xte, 20)
                pred_sample_mean = torch.mean(pred_samples,0)
                if self.Y_mean is not None:
                    pred_sample_te = pred_sample_mean*self.Y_std + self.Y_mean
                rmse = torch.sqrt(torch.mean(torch.square(pred_sample_te - Yte)))
                nrmse = rmse/torch.std(Yte)
                print('epoch = %d,post mean, test rmse=%g, nrmse=%g'%(epoch,rmse,nrmse))

            if self.Y_mean is not None:
                pred_te = pred_te*self.Y_std + self.Y_mean
            rmse = torch.sqrt(torch.mean(torch.square(pred_te - Yte)))
            rmse2 = torch.sqrt(torch.mean(torch.square(pred_te - Yte)))/torch.sqrt(torch.square(Yte).mean())
            
            mae = torch.mean(torch.abs(pred_te - Yte))
            nrmse = rmse/torch.sqrt(torch.square(Yte).mean()) #torch.std(Yte)
            nmae = mae/torch.sqrt(torch.square(Yte).mean()) #torch.std(Yte)
            
            epochs[self.i] = epoch
            test_rmse[self.i] = rmse
            test_nrmse[self.i] = nrmse
            test_mae[self.i] = mae
            test_nmae[self.i] = nmae
            print(self.log_ls)
            print('epoch=%d, tau=%g, train_err = %g, test_rmse=%g, test nrmse=%g, test_mae=%g, test nmae=%g' %\
                 (epoch, torch.exp(self.log_tau), err_tr, rmse, rmse2, mae, nmae))

#             print(epochs[self.i])
            self.i += 1

def test_heat():
    Xtr = np.load('Xtr.npy')
    Xte = np.load('Xte.npy')
    ytr = np.load('ytr.npy').reshape((-1, 64, 64))
    yte = np.load('yte.npy').reshape((-1, 64, 64))
#     ttr = np.load('ttr.npy')
#     tte = np.load('tte.npy')

#     Xtr = np.load('data/heat/Xtr.npy')
#     Xte = np.load('data/heat/Xte.npy')
#     ytr = np.load('data/heat/ytr.npy').reshape((-1, 64, 64))
#     yte = np.load('data/heat/yte.npy').reshape((-1, 64, 64))
#     ttr = np.load('data/heat/ttr.npy')
#     tte = np.load('data/heat/tte.npy')

#     Xtr = np.hstack((Xtr, ttr))
#     Xte = np.hstack((Xte, tte))
    hgp = HoGPR(Xtr, ytr, 5, torch.device('cpu'))
    lr = 1e-3
    hgp.train(Xte, yte, lr, 10000)


if __name__ == '__main__':
    #test_canti()
    test_heat()
# Out:
# [tensor([0.0010, 0.0010, 0.0010], requires_grad=True), tensor([0.0010, 0.0010, 0.0010, 0.0010, 0.0010], requires_grad=True), tensor([ 0.0010, -0.0010,  0.0010, -0.0010,  0.0010], requires_grad=True)]
# epoch=0, tau=1.001, train_err = 0.185833, test_rmse=0.296871, test nrmse=0.316022, test_mae=0.1728, test nmae=0.183947
# [tensor([0.0060, 0.0060, 0.0060], requires_grad=True), tensor([0.0060, 0.0060, 0.0060, 0.0060, 0.0060], requires_grad=True), tensor([ 0.0060, -0.0055,  0.0060, -0.0060,  0.0060], requires_grad=True)]
# epoch=5, tau=1.00602, train_err = 0.18259, test_rmse=0.293759, test nrmse=0.312709, test_mae=0.170669, test nmae=0.181679
# [tensor([0.0110, 0.0110, 0.0110], requires_grad=True), tensor([0.0110, 0.0110, 0.0110, 0.0110, 0.0110], requires_grad=True), tensor([ 0.0111, -0.0068,  0.0112, -0.0109,  0.0111], requires_grad=True)]
# epoch=10, tau=1.01106, train_err = 0.179554, test_rmse=0.290785, test nrmse=0.309543, test_mae=0.168657, test nmae=0.179537
# [tensor([0.0160, 0.0160, 0.0160], requires_grad=True), tensor([0.0160, 0.0160, 0.0160, 0.0160, 0.0160], requires_grad=True), tensor([ 0.0164, -0.0038,  0.0166, -0.0157,  0.0163], requires_grad=True)]
# epoch=15, tau=1.01614, train_err = 0.176692, test_rmse=0.287931, test nrmse=0.306505, test_mae=0.166749, test nmae=0.177506
# [tensor([0.0210, 0.0210, 0.0210], requires_grad=True), tensor([0.0210, 0.0210, 0.0210, 0.0210, 0.0210], requires_grad=True), tensor([ 0.0218,  0.0011,  0.0221, -0.0204,  0.0217], requires_grad=True)]
# epoch=20, tau=1.02124, train_err = 0.17397, test_rmse=0.285176, test nrmse=0.303573, test_mae=0.164932, test nmae=0.175572
# [tensor([0.0260, 0.0260, 0.0260], requires_grad=True), tensor([0.0260, 0.0260, 0.0260, 0.0260, 0.0260], requires_grad=True), tensor([ 0.0273,  0.0068,  0.0279, -0.0248,  0.0272], requires_grad=True)]
# epoch=25, tau=1.02637, train_err = 0.17138, test_rmse=0.282513, test nrmse=0.300738, test_mae=0.163199, test nmae=0.173727
# [tensor([0.0309, 0.0309, 0.0310], requires_grad=True), tensor([0.0310, 0.0310, 0.0310, 0.0310, 0.0310], requires_grad=True), tensor([ 0.0330,  0.0130,  0.0339, -0.0290,  0.0329], requires_grad=True)]
# epoch=30, tau=1.03153, train_err = 0.168916, test_rmse=0.279939, test nrmse=0.297998, test_mae=0.161545, test nmae=0.171967
# [tensor([0.0359, 0.0359, 0.0360], requires_grad=True), tensor([0.0359, 0.0360, 0.0359, 0.0359, 0.0360], requires_grad=True), tensor([ 0.0389,  0.0195,  0.0400, -0.0328,  0.0387], requires_grad=True)]
# epoch=35, tau=1.03672, train_err = 0.166571, test_rmse=0.277448, test nrmse=0.295346, test_mae=0.159966, test nmae=0.170285
# [tensor([0.0409, 0.0409, 0.0409], requires_grad=True), tensor([0.0409, 0.0410, 0.0409, 0.0409, 0.0410], requires_grad=True), tensor([ 0.0448,  0.0263,  0.0464, -0.0363,  0.0446], requires_grad=True)]
# epoch=40, tau=1.04195, train_err = 0.164339, test_rmse=0.275036, test nrmse=0.292778, test_mae=0.158456, test nmae=0.168678
# [tensor([0.0458, 0.0458, 0.0459], requires_grad=True), tensor([0.0459, 0.0460, 0.0459, 0.0459, 0.0460], requires_grad=True), tensor([ 0.0510,  0.0332,  0.0528, -0.0394,  0.0507], requires_grad=True)]
# epoch=45, tau=1.0472, train_err = 0.162215, test_rmse=0.2727, test nrmse=0.290291, test_mae=0.157014, test nmae=0.167143
# [tensor([0.0507, 0.0507, 0.0509], requires_grad=True), tensor([0.0508, 0.0510, 0.0508, 0.0508, 0.0510], requires_grad=True), tensor([ 0.0572,  0.0403,  0.0594, -0.0421,  0.0568], requires_grad=True)]
# epoch=50, tau=1.05249, train_err = 0.160196, test_rmse=0.270436, test nrmse=0.287881, test_mae=0.155638, test nmae=0.165678
# [tensor([0.0557, 0.0557, 0.0558], requires_grad=True), tensor([0.0558, 0.0561, 0.0558, 0.0558, 0.0560], requires_grad=True), tensor([ 0.0635,  0.0474,  0.0661, -0.0443,  0.0631], requires_grad=True)]
# epoch=55, tau=1.05781, train_err = 0.158278, test_rmse=0.268242, test nrmse=0.285546, test_mae=0.154324, test nmae=0.164279
# [tensor([0.0606, 0.0606, 0.0608], requires_grad=True), tensor([0.0607, 0.0611, 0.0607, 0.0607, 0.0610], requires_grad=True), tensor([ 0.0698,  0.0547,  0.0728, -0.0460,  0.0694], requires_grad=True)]
# epoch=60, tau=1.06317, train_err = 0.156457, test_rmse=0.266114, test nrmse=0.283281, test_mae=0.153069, test nmae=0.162943
# [tensor([0.0655, 0.0655, 0.0657], requires_grad=True), tensor([0.0657, 0.0661, 0.0656, 0.0656, 0.0660], requires_grad=True), tensor([ 0.0762,  0.0620,  0.0797, -0.0471,  0.0759], requires_grad=True)]
# epoch=65, tau=1.06856, train_err = 0.154731, test_rmse=0.264052, test nrmse=0.281086, test_mae=0.151872, test nmae=0.161669
# [tensor([0.0704, 0.0704, 0.0707], requires_grad=True), tensor([0.0706, 0.0710, 0.0705, 0.0705, 0.0710], requires_grad=True), tensor([ 0.0827,  0.0694,  0.0866, -0.0476,  0.0824], requires_grad=True)]
# epoch=70, tau=1.07398, train_err = 0.153098, test_rmse=0.262054, test nrmse=0.278959, test_mae=0.150732, test nmae=0.160455
# [tensor([0.0753, 0.0753, 0.0756], requires_grad=True), tensor([0.0755, 0.0760, 0.0754, 0.0754, 0.0760], requires_grad=True), tensor([ 0.0892,  0.0767,  0.0935, -0.0475,  0.0889], requires_grad=True)]
# epoch=75, tau=1.07944, train_err = 0.151556, test_rmse=0.260118, test nrmse=0.276898, test_mae=0.149646, test nmae=0.159299
# [tensor([0.0801, 0.0802, 0.0805], requires_grad=True), tensor([0.0804, 0.0810, 0.0803, 0.0803, 0.0809], requires_grad=True), tensor([ 0.0957,  0.0841,  0.1005, -0.0468,  0.0955], requires_grad=True)]
# epoch=80, tau=1.08493, train_err = 0.150101, test_rmse=0.258242, test nrmse=0.274901, test_mae=0.148612, test nmae=0.158199
# [tensor([0.0850, 0.0850, 0.0855], requires_grad=True), tensor([0.0853, 0.0860, 0.0851, 0.0852, 0.0859], requires_grad=True), tensor([ 0.1023,  0.0915,  0.1075, -0.0454,  0.1021], requires_grad=True)]
# epoch=85, tau=1.09046, train_err = 0.148733, test_rmse=0.256426, test nrmse=0.272968, test_mae=0.147629, test nmae=0.157152
# [tensor([0.0899, 0.0899, 0.0904], requires_grad=True), tensor([0.0902, 0.0910, 0.0900, 0.0900, 0.0909], requires_grad=True), tensor([ 0.1088,  0.0989,  0.1146, -0.0434,  0.1088], requires_grad=True)]
# epoch=90, tau=1.09603, train_err = 0.147447, test_rmse=0.254666, test nrmse=0.271095, test_mae=0.146693, test nmae=0.156156
# [tensor([0.0947, 0.0947, 0.0953], requires_grad=True), tensor([0.0951, 0.0960, 0.0948, 0.0949, 0.0958], requires_grad=True), tensor([ 0.1154,  0.1063,  0.1217, -0.0409,  0.1154], requires_grad=True)]
# epoch=95, tau=1.10163, train_err = 0.146239, test_rmse=0.252961, test nrmse=0.26928, test_mae=0.145802, test nmae=0.155208
# [tensor([0.0995, 0.0995, 0.1001], requires_grad=True), tensor([0.1000, 0.1009, 0.0996, 0.0997, 0.1008], requires_grad=True), tensor([ 0.1219,  0.1137,  0.1288, -0.0377,  0.1221], requires_grad=True)]
# epoch=100, tau=1.10726, train_err = 0.145105, test_rmse=0.251308, test nrmse=0.267519, test_mae=0.144954, test nmae=0.154305
# [tensor([0.1043, 0.1043, 0.1050], requires_grad=True), tensor([0.1049, 0.1059, 0.1044, 0.1045, 0.1057], requires_grad=True), tensor([ 0.1285,  0.1210,  0.1359, -0.0340,  0.1288], requires_grad=True)]
# epoch=105, tau=1.11293, train_err = 0.14404, test_rmse=0.249703, test nrmse=0.265811, test_mae=0.144145, test nmae=0.153443
# [tensor([0.1091, 0.1091, 0.1099], requires_grad=True), tensor([0.1097, 0.1109, 0.1092, 0.1093, 0.1106], requires_grad=True), tensor([ 0.1350,  0.1283,  0.1430, -0.0298,  0.1355], requires_grad=True)]
# epoch=110, tau=1.11864, train_err = 0.143038, test_rmse=0.248144, test nrmse=0.264152, test_mae=0.143371, test nmae=0.15262
# [tensor([0.1139, 0.1139, 0.1148], requires_grad=True), tensor([0.1146, 0.1159, 0.1139, 0.1140, 0.1155], requires_grad=True), tensor([ 0.1415,  0.1355,  0.1501, -0.0252,  0.1422], requires_grad=True)]
# epoch=115, tau=1.12439, train_err = 0.142096, test_rmse=0.246628, test nrmse=0.262538, test_mae=0.142631, test nmae=0.151832
# [tensor([0.1187, 0.1187, 0.1196], requires_grad=True), tensor([0.1194, 0.1208, 0.1186, 0.1188, 0.1204], requires_grad=True), tensor([ 0.1480,  0.1428,  0.1573, -0.0201,  0.1490], requires_grad=True)]
# epoch=120, tau=1.13017, train_err = 0.141208, test_rmse=0.245152, test nrmse=0.260967, test_mae=0.141921, test nmae=0.151076
# [tensor([0.1234, 0.1234, 0.1244], requires_grad=True), tensor([0.1242, 0.1258, 0.1234, 0.1235, 0.1253], requires_grad=True), tensor([ 0.1545,  0.1499,  0.1644, -0.0147,  0.1557], requires_grad=True)]
# epoch=125, tau=1.13599, train_err = 0.140371, test_rmse=0.243715, test nrmse=0.259437, test_mae=0.14124, test nmae=0.150351
# [tensor([0.1282, 0.1282, 0.1293], requires_grad=True), tensor([0.1291, 0.1307, 0.1281, 0.1282, 0.1302], requires_grad=True), tensor([ 0.1610,  0.1571,  0.1715, -0.0090,  0.1623], requires_grad=True)]
# epoch=130, tau=1.14185, train_err = 0.139582, test_rmse=0.242314, test nrmse=0.257946, test_mae=0.140587, test nmae=0.149656
# [tensor([0.1329, 0.1329, 0.1341], requires_grad=True), tensor([0.1339, 0.1357, 0.1327, 0.1329, 0.1351], requires_grad=True), tensor([ 0.1674,  0.1641,  0.1786, -0.0030,  0.1690], requires_grad=True)]
# epoch=135, tau=1.14775, train_err = 0.138838, test_rmse=0.240949, test nrmse=0.256492, test_mae=0.13996, test nmae=0.148988
# [tensor([0.1376, 0.1376, 0.1389], requires_grad=True), tensor([0.1386, 0.1406, 0.1374, 0.1376, 0.1400], requires_grad=True), tensor([0.1739, 0.1711, 0.1857, 0.0032, 0.1757], requires_grad=True)]
# epoch=140, tau=1.15368, train_err = 0.138137, test_rmse=0.239617, test nrmse=0.255075, test_mae=0.139358, test nmae=0.148348
# [tensor([0.1423, 0.1423, 0.1437], requires_grad=True), tensor([0.1434, 0.1456, 0.1420, 0.1423, 0.1448], requires_grad=True), tensor([0.1803, 0.1781, 0.1928, 0.0095, 0.1823], requires_grad=True)]
# epoch=145, tau=1.15966, train_err = 0.137477, test_rmse=0.238319, test nrmse=0.253693, test_mae=0.13878, test nmae=0.147733
# [tensor([0.1470, 0.1470, 0.1484], requires_grad=True), tensor([0.1482, 0.1505, 0.1466, 0.1469, 0.1496], requires_grad=True), tensor([0.1866, 0.1850, 0.1999, 0.0161, 0.1889], requires_grad=True)]
# epoch=150, tau=1.16567, train_err = 0.136856, test_rmse=0.237052, test nrmse=0.252344, test_mae=0.138227, test nmae=0.147144
# [tensor([0.1516, 0.1517, 0.1532], requires_grad=True), tensor([0.1529, 0.1555, 0.1512, 0.1516, 0.1545], requires_grad=True), tensor([0.1930, 0.1918, 0.2069, 0.0227, 0.1955], requires_grad=True)]
# epoch=155, tau=1.17173, train_err = 0.136274, test_rmse=0.235817, test nrmse=0.25103, test_mae=0.137697, test nmae=0.146579
# [tensor([0.1563, 0.1563, 0.1579], requires_grad=True), tensor([0.1576, 0.1604, 0.1558, 0.1562, 0.1593], requires_grad=True), tensor([0.1993, 0.1986, 0.2139, 0.0295, 0.2021], requires_grad=True)]
# epoch=160, tau=1.17782, train_err = 0.135729, test_rmse=0.234613, test nrmse=0.249748, test_mae=0.13719, test nmae=0.14604
# [tensor([0.1609, 0.1609, 0.1626], requires_grad=True), tensor([0.1623, 0.1653, 0.1603, 0.1608, 0.1640], requires_grad=True), tensor([0.2055, 0.2053, 0.2209, 0.0363, 0.2086], requires_grad=True)]
# epoch=165, tau=1.18395, train_err = 0.13522, test_rmse=0.23344, test nrmse=0.248499, test_mae=0.136706, test nmae=0.145525
# [tensor([0.1655, 0.1656, 0.1673], requires_grad=True), tensor([0.1669, 0.1703, 0.1649, 0.1654, 0.1688], requires_grad=True), tensor([0.2118, 0.2119, 0.2279, 0.0431, 0.2150], requires_grad=True)]
# epoch=170, tau=1.19013, train_err = 0.134745, test_rmse=0.232296, test nrmse=0.247281, test_mae=0.136244, test nmae=0.145033
# [tensor([0.1701, 0.1702, 0.1720], requires_grad=True), tensor([0.1716, 0.1752, 0.1694, 0.1700, 0.1735], requires_grad=True), tensor([0.2180, 0.2185, 0.2348, 0.0501, 0.2215], requires_grad=True)]
# epoch=175, tau=1.19635, train_err = 0.134304, test_rmse=0.231181, test nrmse=0.246095, test_mae=0.135803, test nmae=0.144563
# [tensor([0.1747, 0.1747, 0.1767], requires_grad=True), tensor([0.1762, 0.1801, 0.1738, 0.1745, 0.1782], requires_grad=True), tensor([0.2242, 0.2250, 0.2417, 0.0570, 0.2279], requires_grad=True)]
# epoch=180, tau=1.20261, train_err = 0.133895, test_rmse=0.230095, test nrmse=0.244939, test_mae=0.135383, test nmae=0.144116
# [tensor([0.1793, 0.1793, 0.1814], requires_grad=True), tensor([0.1807, 0.1850, 0.1783, 0.1791, 0.1829], requires_grad=True), tensor([0.2303, 0.2315, 0.2485, 0.0640, 0.2342], requires_grad=True)]
# epoch=185, tau=1.20891, train_err = 0.133517, test_rmse=0.229037, test nrmse=0.243812, test_mae=0.134983, test nmae=0.143691
# [tensor([0.1838, 0.1839, 0.1860], requires_grad=True), tensor([0.1853, 0.1899, 0.1827, 0.1836, 0.1876], requires_grad=True), tensor([0.2364, 0.2379, 0.2554, 0.0709, 0.2405], requires_grad=True)]
# epoch=190, tau=1.21525, train_err = 0.133168, test_rmse=0.228006, test nrmse=0.242715, test_mae=0.134604, test nmae=0.143287
# [tensor([0.1883, 0.1884, 0.1906], requires_grad=True), tensor([0.1898, 0.1947, 0.1871, 0.1881, 0.1923], requires_grad=True), tensor([0.2425, 0.2442, 0.2621, 0.0779, 0.2467], requires_grad=True)]
# epoch=195, tau=1.22163, train_err = 0.132848, test_rmse=0.227002, test nrmse=0.241646, test_mae=0.134243, test nmae=0.142903
# [tensor([0.1928, 0.1929, 0.1953], requires_grad=True), tensor([0.1942, 0.1996, 0.1915, 0.1926, 0.1969], requires_grad=True), tensor([0.2485, 0.2505, 0.2689, 0.0849, 0.2529], requires_grad=True)]
# epoch=200, tau=1.22806, train_err = 0.132556, test_rmse=0.226024, test nrmse=0.240605, test_mae=0.133899, test nmae=0.142536
# [tensor([0.1973, 0.1974, 0.1998], requires_grad=True), tensor([0.1987, 0.2044, 0.1959, 0.1971, 0.2015], requires_grad=True), tensor([0.2545, 0.2568, 0.2755, 0.0919, 0.2590], requires_grad=True)]
# epoch=205, tau=1.23453, train_err = 0.13229, test_rmse=0.225071, test nrmse=0.23959, test_mae=0.133571, test nmae=0.142187
# [tensor([0.2018, 0.2019, 0.2044], requires_grad=True), tensor([0.2031, 0.2092, 0.2002, 0.2015, 0.2061], requires_grad=True), tensor([0.2604, 0.2630, 0.2822, 0.0989, 0.2650], requires_grad=True)]
# epoch=210, tau=1.24104, train_err = 0.132048, test_rmse=0.224142, test nrmse=0.238601, test_mae=0.133257, test nmae=0.141854
# [tensor([0.2063, 0.2064, 0.2090], requires_grad=True), tensor([0.2074, 0.2140, 0.2045, 0.2060, 0.2106], requires_grad=True), tensor([0.2663, 0.2691, 0.2888, 0.1059, 0.2710], requires_grad=True)]
# epoch=215, tau=1.24759, train_err = 0.131828, test_rmse=0.223234, test nrmse=0.237635, test_mae=0.132956, test nmae=0.141533
# [tensor([0.2107, 0.2108, 0.2135], requires_grad=True), tensor([0.2117, 0.2188, 0.2088, 0.2104, 0.2151], requires_grad=True), tensor([0.2722, 0.2752, 0.2953, 0.1129, 0.2769], requires_grad=True)]
# epoch=220, tau=1.25419, train_err = 0.131626, test_rmse=0.222347, test nrmse=0.23669, test_mae=0.132665, test nmae=0.141223
# [tensor([0.2151, 0.2152, 0.2180], requires_grad=True), tensor([0.2160, 0.2236, 0.2131, 0.2148, 0.2196], requires_grad=True), tensor([0.2780, 0.2813, 0.3018, 0.1199, 0.2828], requires_grad=True)]
# epoch=225, tau=1.26083, train_err = 0.131438, test_rmse=0.221477, test nrmse=0.235764, test_mae=0.132382, test nmae=0.140922
# [tensor([0.2195, 0.2196, 0.2225], requires_grad=True), tensor([0.2202, 0.2283, 0.2173, 0.2193, 0.2241], requires_grad=True), tensor([0.2838, 0.2873, 0.3082, 0.1269, 0.2886], requires_grad=True)]
# epoch=230, tau=1.26751, train_err = 0.131262, test_rmse=0.220623, test nrmse=0.234855, test_mae=0.132105, test nmae=0.140626
# [tensor([0.2239, 0.2240, 0.2270], requires_grad=True), tensor([0.2244, 0.2330, 0.2215, 0.2236, 0.2285], requires_grad=True), tensor([0.2896, 0.2933, 0.3145, 0.1339, 0.2943], requires_grad=True)]
# epoch=235, tau=1.27424, train_err = 0.131094, test_rmse=0.219783, test nrmse=0.23396, test_mae=0.131831, test nmae=0.140335
# [tensor([0.2283, 0.2284, 0.2315], requires_grad=True), tensor([0.2285, 0.2376, 0.2257, 0.2280, 0.2330], requires_grad=True), tensor([0.2953, 0.2993, 0.3208, 0.1409, 0.2999], requires_grad=True)]
# epoch=240, tau=1.28101, train_err = 0.130933, test_rmse=0.218955, test nrmse=0.23308, test_mae=0.131559, test nmae=0.140046
# [tensor([0.2326, 0.2328, 0.2360], requires_grad=True), tensor([0.2326, 0.2423, 0.2298, 0.2324, 0.2373], requires_grad=True), tensor([0.3010, 0.3052, 0.3271, 0.1479, 0.3055], requires_grad=True)]
# epoch=245, tau=1.28783, train_err = 0.130778, test_rmse=0.218139, test nrmse=0.232211, test_mae=0.131289, test nmae=0.139759
# [tensor([0.2370, 0.2371, 0.2404], requires_grad=True), tensor([0.2366, 0.2469, 0.2339, 0.2367, 0.2417], requires_grad=True), tensor([0.3066, 0.3112, 0.3333, 0.1549, 0.3109], requires_grad=True)]
# epoch=250, tau=1.29468, train_err = 0.130627, test_rmse=0.217335, test nrmse=0.231355, test_mae=0.13102, test nmae=0.139472
# [tensor([0.2413, 0.2415, 0.2448], requires_grad=True), tensor([0.2406, 0.2515, 0.2380, 0.2411, 0.2460], requires_grad=True), tensor([0.3123, 0.3172, 0.3394, 0.1619, 0.3164], requires_grad=True)]
# epoch=255, tau=1.30159, train_err = 0.13048, test_rmse=0.216541, test nrmse=0.23051, test_mae=0.13075, test nmae=0.139185
# [tensor([0.2456, 0.2458, 0.2492], requires_grad=True), tensor([0.2446, 0.2560, 0.2421, 0.2454, 0.2503], requires_grad=True), tensor([0.3179, 0.3231, 0.3454, 0.1689, 0.3217], requires_grad=True)]
# epoch=260, tau=1.30853, train_err = 0.130336, test_rmse=0.215757, test nrmse=0.229675, test_mae=0.130481, test nmae=0.138898
# [tensor([0.2499, 0.2501, 0.2536], requires_grad=True), tensor([0.2485, 0.2605, 0.2462, 0.2497, 0.2546], requires_grad=True), tensor([0.3235, 0.3291, 0.3514, 0.1759, 0.3270], requires_grad=True)]
# epoch=265, tau=1.31552, train_err = 0.130194, test_rmse=0.214982, test nrmse=0.22885, test_mae=0.13021, test nmae=0.13861
# [tensor([0.2542, 0.2544, 0.2580], requires_grad=True), tensor([0.2523, 0.2650, 0.2502, 0.2540, 0.2589], requires_grad=True), tensor([0.3290, 0.3351, 0.3573, 0.1829, 0.3323], requires_grad=True)]
# epoch=270, tau=1.32255, train_err = 0.130054, test_rmse=0.214217, test nrmse=0.228036, test_mae=0.129938, test nmae=0.13832
# [tensor([0.2584, 0.2586, 0.2623], requires_grad=True), tensor([0.2561, 0.2694, 0.2542, 0.2583, 0.2631], requires_grad=True), tensor([0.3346, 0.3411, 0.3631, 0.1899, 0.3374], requires_grad=True)]
# epoch=275, tau=1.32963, train_err = 0.129916, test_rmse=0.213461, test nrmse=0.227231, test_mae=0.129666, test nmae=0.13803
# [tensor([0.2627, 0.2629, 0.2667], requires_grad=True), tensor([0.2599, 0.2738, 0.2581, 0.2625, 0.2673], requires_grad=True), tensor([0.3401, 0.3471, 0.3689, 0.1969, 0.3426], requires_grad=True)]
# epoch=280, tau=1.33675, train_err = 0.12978, test_rmse=0.212714, test nrmse=0.226436, test_mae=0.129392, test nmae=0.137739
# [tensor([0.2669, 0.2671, 0.2710], requires_grad=True), tensor([0.2637, 0.2782, 0.2621, 0.2667, 0.2714], requires_grad=True), tensor([0.3456, 0.3531, 0.3746, 0.2039, 0.3476], requires_grad=True)]
# epoch=285, tau=1.34392, train_err = 0.129648, test_rmse=0.211978, test nrmse=0.225652, test_mae=0.129118, test nmae=0.137448
# [tensor([0.2711, 0.2713, 0.2753], requires_grad=True), tensor([0.2673, 0.2825, 0.2660, 0.2710, 0.2756], requires_grad=True), tensor([0.3511, 0.3592, 0.3802, 0.2108, 0.3526], requires_grad=True)]
# epoch=290, tau=1.35113, train_err = 0.129521, test_rmse=0.211252, test nrmse=0.22488, test_mae=0.128845, test nmae=0.137156
# [tensor([0.2753, 0.2755, 0.2796], requires_grad=True), tensor([0.2710, 0.2868, 0.2699, 0.2752, 0.2797], requires_grad=True), tensor([0.3565, 0.3653, 0.3857, 0.2177, 0.3576], requires_grad=True)]
# epoch=295, tau=1.35838, train_err = 0.1294, test_rmse=0.210538, test nrmse=0.22412, test_mae=0.128572, test nmae=0.136866
# [tensor([0.2795, 0.2797, 0.2838], requires_grad=True), tensor([0.2746, 0.2911, 0.2738, 0.2794, 0.2837], requires_grad=True), tensor([0.3620, 0.3713, 0.3912, 0.2246, 0.3625], requires_grad=True)]
# epoch=300, tau=1.36568, train_err = 0.129287, test_rmse=0.209837, test nrmse=0.223373, test_mae=0.128303, test nmae=0.136579
# [tensor([0.2836, 0.2839, 0.2881], requires_grad=True), tensor([0.2782, 0.2953, 0.2776, 0.2835, 0.2878], requires_grad=True), tensor([0.3674, 0.3775, 0.3966, 0.2316, 0.3674], requires_grad=True)]
# epoch=305, tau=1.37302, train_err = 0.129185, test_rmse=0.20915, test nrmse=0.222642, test_mae=0.128038, test nmae=0.136298
# [tensor([0.2878, 0.2880, 0.2923], requires_grad=True), tensor([0.2817, 0.2996, 0.2815, 0.2877, 0.2918], requires_grad=True), tensor([0.3728, 0.3836, 0.4019, 0.2384, 0.3723], requires_grad=True)]
# epoch=310, tau=1.38041, train_err = 0.129096, test_rmse=0.208478, test nrmse=0.221927, test_mae=0.12778, test nmae=0.136023
# [tensor([0.2919, 0.2922, 0.2965], requires_grad=True), tensor([0.2853, 0.3037, 0.2853, 0.2918, 0.2957], requires_grad=True), tensor([0.3781, 0.3898, 0.4071, 0.2453, 0.3771], requires_grad=True)]
# epoch=315, tau=1.38784, train_err = 0.129021, test_rmse=0.207823, test nrmse=0.22123, test_mae=0.127529, test nmae=0.135756
# [tensor([0.2960, 0.2963, 0.3007], requires_grad=True), tensor([0.2887, 0.3079, 0.2891, 0.2959, 0.2997], requires_grad=True), tensor([0.3835, 0.3959, 0.4122, 0.2522, 0.3818], requires_grad=True)]
# epoch=320, tau=1.39532, train_err = 0.128962, test_rmse=0.207185, test nrmse=0.220551, test_mae=0.127288, test nmae=0.135499
# [tensor([0.3001, 0.3004, 0.3049], requires_grad=True), tensor([0.2922, 0.3120, 0.2928, 0.2999, 0.3036], requires_grad=True), tensor([0.3888, 0.4021, 0.4173, 0.2591, 0.3866], requires_grad=True)]
# epoch=325, tau=1.40284, train_err = 0.12892, test_rmse=0.206565, test nrmse=0.21989, test_mae=0.127055, test nmae=0.135251
# [tensor([0.3042, 0.3045, 0.3091], requires_grad=True), tensor([0.2956, 0.3161, 0.2966, 0.3040, 0.3074], requires_grad=True), tensor([0.3941, 0.4083, 0.4223, 0.2660, 0.3913], requires_grad=True)]
# epoch=330, tau=1.41041, train_err = 0.128895, test_rmse=0.205962, test nrmse=0.219248, test_mae=0.126833, test nmae=0.135014
# [tensor([0.3083, 0.3086, 0.3133], requires_grad=True), tensor([0.2990, 0.3201, 0.3004, 0.3080, 0.3112], requires_grad=True), tensor([0.3993, 0.4145, 0.4272, 0.2729, 0.3959], requires_grad=True)]
# epoch=335, tau=1.41802, train_err = 0.128885, test_rmse=0.205375, test nrmse=0.218624, test_mae=0.126619, test nmae=0.134787
# [tensor([0.3123, 0.3127, 0.3174], requires_grad=True), tensor([0.3024, 0.3242, 0.3041, 0.3120, 0.3150], requires_grad=True), tensor([0.4045, 0.4207, 0.4321, 0.2797, 0.4006], requires_grad=True)]
# epoch=340, tau=1.42567, train_err = 0.128889, test_rmse=0.204805, test nrmse=0.218016, test_mae=0.126413, test nmae=0.134568
# [tensor([0.3164, 0.3167, 0.3215], requires_grad=True), tensor([0.3058, 0.3281, 0.3078, 0.3160, 0.3188], requires_grad=True), tensor([0.4097, 0.4269, 0.4369, 0.2866, 0.4052], requires_grad=True)]
# epoch=345, tau=1.43337, train_err = 0.128904, test_rmse=0.204248, test nrmse=0.217424, test_mae=0.126213, test nmae=0.134355
# [tensor([0.3204, 0.3208, 0.3256], requires_grad=True), tensor([0.3092, 0.3321, 0.3115, 0.3199, 0.3225], requires_grad=True), tensor([0.4148, 0.4332, 0.4416, 0.2936, 0.4097], requires_grad=True)]
# epoch=350, tau=1.44111, train_err = 0.128928, test_rmse=0.203704, test nrmse=0.216845, test_mae=0.126018, test nmae=0.134147
# [tensor([0.3244, 0.3248, 0.3297], requires_grad=True), tensor([0.3125, 0.3361, 0.3152, 0.3238, 0.3262], requires_grad=True), tensor([0.4200, 0.4394, 0.4463, 0.3005, 0.4143], requires_grad=True)]
# epoch=355, tau=1.4489, train_err = 0.128959, test_rmse=0.203171, test nrmse=0.216278, test_mae=0.125825, test nmae=0.133942
# [tensor([0.3284, 0.3288, 0.3338], requires_grad=True), tensor([0.3159, 0.3400, 0.3189, 0.3277, 0.3298], requires_grad=True), tensor([0.4250, 0.4456, 0.4509, 0.3074, 0.4188], requires_grad=True)]
# epoch=360, tau=1.45673, train_err = 0.128993, test_rmse=0.202647, test nrmse=0.21572, test_mae=0.125634, test nmae=0.133738
# [tensor([0.3324, 0.3328, 0.3378], requires_grad=True), tensor([0.3192, 0.3439, 0.3225, 0.3316, 0.3334], requires_grad=True), tensor([0.4301, 0.4519, 0.4555, 0.3144, 0.4232], requires_grad=True)]
# epoch=365, tau=1.46461, train_err = 0.129027, test_rmse=0.20213, test nrmse=0.21517, test_mae=0.125442, test nmae=0.133534
# [tensor([0.3364, 0.3368, 0.3419], requires_grad=True), tensor([0.3226, 0.3477, 0.3262, 0.3354, 0.3370], requires_grad=True), tensor([0.4350, 0.4581, 0.4600, 0.3214, 0.4277], requires_grad=True)]
# epoch=370, tau=1.47253, train_err = 0.129059, test_rmse=0.201619, test nrmse=0.214625, test_mae=0.125249, test nmae=0.133328
# [tensor([0.3403, 0.3408, 0.3459], requires_grad=True), tensor([0.3259, 0.3516, 0.3298, 0.3392, 0.3406], requires_grad=True), tensor([0.4400, 0.4643, 0.4645, 0.3284, 0.4320], requires_grad=True)]
# epoch=375, tau=1.4805, train_err = 0.129088, test_rmse=0.201112, test nrmse=0.214086, test_mae=0.125052, test nmae=0.133119
# [tensor([0.3443, 0.3447, 0.3499], requires_grad=True), tensor([0.3292, 0.3554, 0.3334, 0.3430, 0.3441], requires_grad=True), tensor([0.4449, 0.4706, 0.4690, 0.3354, 0.4364], requires_grad=True)]
# epoch=380, tau=1.48851, train_err = 0.129111, test_rmse=0.200608, test nrmse=0.213549, test_mae=0.124852, test nmae=0.132906
# [tensor([0.3482, 0.3487, 0.3539], requires_grad=True), tensor([0.3325, 0.3591, 0.3370, 0.3468, 0.3475], requires_grad=True), tensor([0.4498, 0.4768, 0.4734, 0.3424, 0.4407], requires_grad=True)]
# epoch=385, tau=1.49657, train_err = 0.129127, test_rmse=0.200107, test nrmse=0.213016, test_mae=0.124647, test nmae=0.132688
# [tensor([0.3521, 0.3526, 0.3579], requires_grad=True), tensor([0.3359, 0.3629, 0.3407, 0.3506, 0.3510], requires_grad=True), tensor([0.4546, 0.4831, 0.4777, 0.3494, 0.4449], requires_grad=True)]
# epoch=390, tau=1.50467, train_err = 0.129134, test_rmse=0.199608, test nrmse=0.212484, test_mae=0.124437, test nmae=0.132464
# [tensor([0.3561, 0.3566, 0.3619], requires_grad=True), tensor([0.3392, 0.3666, 0.3443, 0.3543, 0.3544], requires_grad=True), tensor([0.4594, 0.4893, 0.4821, 0.3565, 0.4492], requires_grad=True)]
# epoch=395, tau=1.51281, train_err = 0.129131, test_rmse=0.199108, test nrmse=0.211953, test_mae=0.124221, test nmae=0.132234
# [tensor([0.3600, 0.3605, 0.3658], requires_grad=True), tensor([0.3425, 0.3703, 0.3478, 0.3580, 0.3577], requires_grad=True), tensor([0.4642, 0.4955, 0.4864, 0.3635, 0.4533], requires_grad=True)]
# epoch=400, tau=1.52101, train_err = 0.129115, test_rmse=0.198608, test nrmse=0.21142, test_mae=0.123997, test nmae=0.131996
# [tensor([0.3638, 0.3644, 0.3697], requires_grad=True), tensor([0.3459, 0.3740, 0.3514, 0.3617, 0.3611], requires_grad=True), tensor([0.4689, 0.5018, 0.4906, 0.3706, 0.4575], requires_grad=True)]
# epoch=405, tau=1.52924, train_err = 0.129084, test_rmse=0.198104, test nrmse=0.210883, test_mae=0.123766, test nmae=0.13175
# [tensor([0.3677, 0.3683, 0.3737], requires_grad=True), tensor([0.3492, 0.3777, 0.3550, 0.3653, 0.3644], requires_grad=True), tensor([0.4737, 0.5080, 0.4949, 0.3776, 0.4616], requires_grad=True)]
# epoch=410, tau=1.53753, train_err = 0.129034, test_rmse=0.197595, test nrmse=0.210342, test_mae=0.123525, test nmae=0.131494
# [tensor([0.3716, 0.3721, 0.3776], requires_grad=True), tensor([0.3526, 0.3813, 0.3585, 0.3689, 0.3676], requires_grad=True), tensor([0.4783, 0.5142, 0.4991, 0.3847, 0.4656], requires_grad=True)]
# epoch=415, tau=1.54585, train_err = 0.128962, test_rmse=0.197078, test nrmse=0.209791, test_mae=0.123273, test nmae=0.131225
# [tensor([0.3754, 0.3760, 0.3814], requires_grad=True), tensor([0.3559, 0.3850, 0.3621, 0.3726, 0.3708], requires_grad=True), tensor([0.4830, 0.5205, 0.5033, 0.3917, 0.4696], requires_grad=True)]
# epoch=420, tau=1.55423, train_err = 0.128864, test_rmse=0.19655, test nrmse=0.20923, test_mae=0.123006, test nmae=0.130941
# [tensor([0.3792, 0.3798, 0.3853], requires_grad=True), tensor([0.3593, 0.3886, 0.3656, 0.3761, 0.3740], requires_grad=True), tensor([0.4876, 0.5267, 0.5075, 0.3987, 0.4735], requires_grad=True)]
# epoch=425, tau=1.56265, train_err = 0.128736, test_rmse=0.19601, test nrmse=0.208654, test_mae=0.122724, test nmae=0.130641
# [tensor([0.3831, 0.3837, 0.3892], requires_grad=True), tensor([0.3627, 0.3921, 0.3691, 0.3797, 0.3772], requires_grad=True), tensor([0.4922, 0.5329, 0.5116, 0.4058, 0.4774], requires_grad=True)]
# epoch=430, tau=1.57111, train_err = 0.128577, test_rmse=0.195454, test nrmse=0.208063, test_mae=0.122426, test nmae=0.130324
# [tensor([0.3869, 0.3875, 0.3930], requires_grad=True), tensor([0.3661, 0.3957, 0.3726, 0.3832, 0.3804], requires_grad=True), tensor([0.4968, 0.5391, 0.5157, 0.4128, 0.4813], requires_grad=True)]
# epoch=435, tau=1.57963, train_err = 0.128384, test_rmse=0.194883, test nrmse=0.207455, test_mae=0.122111, test nmae=0.129988
# [tensor([0.3907, 0.3913, 0.3968], requires_grad=True), tensor([0.3695, 0.3992, 0.3760, 0.3868, 0.3835], requires_grad=True), tensor([0.5013, 0.5453, 0.5199, 0.4198, 0.4851], requires_grad=True)]
# epoch=440, tau=1.58819, train_err = 0.128158, test_rmse=0.194295, test nrmse=0.206829, test_mae=0.121778, test nmae=0.129634
# [tensor([0.3944, 0.3951, 0.4006], requires_grad=True), tensor([0.3729, 0.4027, 0.3795, 0.3903, 0.3866], requires_grad=True), tensor([0.5059, 0.5515, 0.5240, 0.4268, 0.4889], requires_grad=True)]
# epoch=445, tau=1.59679, train_err = 0.127901, test_rmse=0.193692, test nrmse=0.206187, test_mae=0.12143, test nmae=0.129263
# [tensor([0.3982, 0.3989, 0.4044], requires_grad=True), tensor([0.3763, 0.4062, 0.3829, 0.3937, 0.3896], requires_grad=True), tensor([0.5104, 0.5576, 0.5280, 0.4337, 0.4926], requires_grad=True)]
# epoch=450, tau=1.60545, train_err = 0.127616, test_rmse=0.193075, test nrmse=0.20553, test_mae=0.121067, test nmae=0.128877
# [tensor([0.4020, 0.4027, 0.4082], requires_grad=True), tensor([0.3798, 0.4097, 0.3864, 0.3972, 0.3927], requires_grad=True), tensor([0.5149, 0.5638, 0.5321, 0.4407, 0.4963], requires_grad=True)]
# epoch=455, tau=1.61415, train_err = 0.127306, test_rmse=0.192446, test nrmse=0.204861, test_mae=0.120694, test nmae=0.12848
# [tensor([0.4057, 0.4064, 0.4119], requires_grad=True), tensor([0.3832, 0.4132, 0.3898, 0.4006, 0.3957], requires_grad=True), tensor([0.5193, 0.5699, 0.5362, 0.4476, 0.4999], requires_grad=True)]
# epoch=460, tau=1.6229, train_err = 0.126976, test_rmse=0.191809, test nrmse=0.204183, test_mae=0.120312, test nmae=0.128073
# [tensor([0.4095, 0.4102, 0.4157], requires_grad=True), tensor([0.3867, 0.4166, 0.3931, 0.4040, 0.3987], requires_grad=True), tensor([0.5238, 0.5760, 0.5402, 0.4545, 0.5035], requires_grad=True)]
# epoch=465, tau=1.6317, train_err = 0.126631, test_rmse=0.191166, test nrmse=0.203498, test_mae=0.119924, test nmae=0.127661
# [tensor([0.4132, 0.4139, 0.4194], requires_grad=True), tensor([0.3901, 0.4200, 0.3965, 0.4073, 0.4017], requires_grad=True), tensor([0.5282, 0.5820, 0.5442, 0.4613, 0.5070], requires_grad=True)]
# epoch=470, tau=1.64055, train_err = 0.126275, test_rmse=0.190519, test nrmse=0.202809, test_mae=0.119534, test nmae=0.127245
# [tensor([0.4169, 0.4176, 0.4231], requires_grad=True), tensor([0.3936, 0.4234, 0.3998, 0.4107, 0.4046], requires_grad=True), tensor([0.5327, 0.5881, 0.5482, 0.4681, 0.5105], requires_grad=True)]
# epoch=475, tau=1.64944, train_err = 0.125911, test_rmse=0.189871, test nrmse=0.202119, test_mae=0.119144, test nmae=0.126829
# [tensor([0.4206, 0.4214, 0.4268], requires_grad=True), tensor([0.3971, 0.4267, 0.4031, 0.4140, 0.4076], requires_grad=True), tensor([0.5371, 0.5941, 0.5522, 0.4749, 0.5140], requires_grad=True)]
# epoch=480, tau=1.65839, train_err = 0.125541, test_rmse=0.189222, test nrmse=0.201428, test_mae=0.118753, test nmae=0.126413
# [tensor([0.4243, 0.4251, 0.4305], requires_grad=True), tensor([0.4006, 0.4301, 0.4064, 0.4173, 0.4105], requires_grad=True), tensor([0.5415, 0.6001, 0.5562, 0.4817, 0.5174], requires_grad=True)]
# epoch=485, tau=1.66738, train_err = 0.125166, test_rmse=0.188572, test nrmse=0.200737, test_mae=0.11836, test nmae=0.125996
# [tensor([0.4280, 0.4288, 0.4342], requires_grad=True), tensor([0.4040, 0.4334, 0.4097, 0.4205, 0.4134], requires_grad=True), tensor([0.5459, 0.6061, 0.5602, 0.4884, 0.5208], requires_grad=True)]
# epoch=490, tau=1.67643, train_err = 0.124784, test_rmse=0.18792, test nrmse=0.200043, test_mae=0.117965, test nmae=0.125575
# [tensor([0.4317, 0.4324, 0.4378], requires_grad=True), tensor([0.4075, 0.4367, 0.4130, 0.4237, 0.4163], requires_grad=True), tensor([0.5503, 0.6120, 0.5641, 0.4951, 0.5241], requires_grad=True)]
# epoch=495, tau=1.68552, train_err = 0.124392, test_rmse=0.187264, test nrmse=0.199345, test_mae=0.117563, test nmae=0.125146
# [tensor([0.4353, 0.4361, 0.4415], requires_grad=True), tensor([0.4110, 0.4400, 0.4162, 0.4269, 0.4192], requires_grad=True), tensor([0.5547, 0.6179, 0.5680, 0.5018, 0.5274], requires_grad=True)]
# epoch=500, tau=1.69467, train_err = 0.123986, test_rmse=0.186601, test nrmse=0.198639, test_mae=0.11715, test nmae=0.124707
# [tensor([0.4390, 0.4398, 0.4451], requires_grad=True), tensor([0.4145, 0.4432, 0.4194, 0.4301, 0.4221], requires_grad=True), tensor([0.5591, 0.6238, 0.5719, 0.5084, 0.5307], requires_grad=True)]
# epoch=505, tau=1.70386, train_err = 0.123562, test_rmse=0.185928, test nrmse=0.197922, test_mae=0.116724, test nmae=0.124254
# [tensor([0.4426, 0.4434, 0.4487], requires_grad=True), tensor([0.4180, 0.4465, 0.4227, 0.4332, 0.4250], requires_grad=True), tensor([0.5635, 0.6296, 0.5758, 0.5150, 0.5339], requires_grad=True)]
# epoch=510, tau=1.7131, train_err = 0.123117, test_rmse=0.185241, test nrmse=0.197191, test_mae=0.116283, test nmae=0.123784
# [tensor([0.4462, 0.4471, 0.4523], requires_grad=True), tensor([0.4214, 0.4497, 0.4259, 0.4364, 0.4278], requires_grad=True), tensor([0.5678, 0.6354, 0.5797, 0.5215, 0.5370], requires_grad=True)]
# epoch=515, tau=1.7224, train_err = 0.12265, test_rmse=0.184542, test nrmse=0.196446, test_mae=0.115824, test nmae=0.123296
# [tensor([0.4499, 0.4507, 0.4559], requires_grad=True), tensor([0.4249, 0.4529, 0.4290, 0.4395, 0.4307], requires_grad=True), tensor([0.5722, 0.6412, 0.5835, 0.5280, 0.5402], requires_grad=True)]
# epoch=520, tau=1.73174, train_err = 0.12216, test_rmse=0.183829, test nrmse=0.195687, test_mae=0.115349, test nmae=0.12279
# [tensor([0.4535, 0.4543, 0.4595], requires_grad=True), tensor([0.4284, 0.4561, 0.4322, 0.4426, 0.4336], requires_grad=True), tensor([0.5766, 0.6469, 0.5874, 0.5345, 0.5432], requires_grad=True)]
# epoch=525, tau=1.74114, train_err = 0.12165, test_rmse=0.183103, test nrmse=0.194915, test_mae=0.114858, test nmae=0.122268
# [tensor([0.4571, 0.4580, 0.4631], requires_grad=True), tensor([0.4319, 0.4593, 0.4354, 0.4456, 0.4364], requires_grad=True), tensor([0.5810, 0.6526, 0.5912, 0.5409, 0.5463], requires_grad=True)]
# epoch=530, tau=1.75058, train_err = 0.12112, test_rmse=0.182365, test nrmse=0.194129, test_mae=0.114352, test nmae=0.121729
# [tensor([0.4607, 0.4616, 0.4666], requires_grad=True), tensor([0.4353, 0.4625, 0.4385, 0.4487, 0.4393], requires_grad=True), tensor([0.5855, 0.6582, 0.5950, 0.5474, 0.5493], requires_grad=True)]
# epoch=535, tau=1.76008, train_err = 0.120571, test_rmse=0.181615, test nrmse=0.193331, test_mae=0.113829, test nmae=0.121173
# [tensor([0.4643, 0.4652, 0.4702], requires_grad=True), tensor([0.4388, 0.4657, 0.4417, 0.4517, 0.4422], requires_grad=True), tensor([0.5899, 0.6638, 0.5988, 0.5538, 0.5522], requires_grad=True)]
# epoch=540, tau=1.76963, train_err = 0.120002, test_rmse=0.180853, test nrmse=0.19252, test_mae=0.113292, test nmae=0.1206
# [tensor([0.4679, 0.4688, 0.4737], requires_grad=True), tensor([0.4423, 0.4689, 0.4448, 0.4548, 0.4451], requires_grad=True), tensor([0.5943, 0.6694, 0.6026, 0.5601, 0.5552], requires_grad=True)]
# epoch=545, tau=1.77922, train_err = 0.119418, test_rmse=0.180082, test nrmse=0.191699, test_mae=0.112741, test nmae=0.120014
# [tensor([0.4715, 0.4724, 0.4773], requires_grad=True), tensor([0.4457, 0.4721, 0.4480, 0.4578, 0.4479], requires_grad=True), tensor([0.5988, 0.6749, 0.6063, 0.5665, 0.5580], requires_grad=True)]
# epoch=550, tau=1.78887, train_err = 0.118823, test_rmse=0.179304, test nrmse=0.190871, test_mae=0.11218, test nmae=0.119417
# [tensor([0.4750, 0.4760, 0.4808], requires_grad=True), tensor([0.4492, 0.4752, 0.4511, 0.4608, 0.4508], requires_grad=True), tensor([0.6033, 0.6803, 0.6101, 0.5728, 0.5608], requires_grad=True)]
# epoch=555, tau=1.79858, train_err = 0.118223, test_rmse=0.178525, test nrmse=0.190042, test_mae=0.111614, test nmae=0.118814
# [tensor([0.4786, 0.4795, 0.4843], requires_grad=True), tensor([0.4527, 0.4784, 0.4542, 0.4639, 0.4537], requires_grad=True), tensor([0.6078, 0.6857, 0.6138, 0.5791, 0.5636], requires_grad=True)]
# epoch=560, tau=1.80833, train_err = 0.117624, test_rmse=0.177749, test nrmse=0.189215, test_mae=0.111048, test nmae=0.118212
# [tensor([0.4822, 0.4831, 0.4878], requires_grad=True), tensor([0.4561, 0.4815, 0.4574, 0.4669, 0.4566], requires_grad=True), tensor([0.6123, 0.6911, 0.6176, 0.5854, 0.5663], requires_grad=True)]
# epoch=565, tau=1.81814, train_err = 0.117031, test_rmse=0.176979, test nrmse=0.188395, test_mae=0.110487, test nmae=0.117615
# [tensor([0.4857, 0.4867, 0.4913], requires_grad=True), tensor([0.4596, 0.4847, 0.4605, 0.4699, 0.4596], requires_grad=True), tensor([0.6168, 0.6963, 0.6213, 0.5917, 0.5690], requires_grad=True)]
# epoch=570, tau=1.828, train_err = 0.116448, test_rmse=0.176217, test nrmse=0.187585, test_mae=0.109934, test nmae=0.117026
# [tensor([0.4892, 0.4902, 0.4948], requires_grad=True), tensor([0.4631, 0.4878, 0.4636, 0.4729, 0.4625], requires_grad=True), tensor([0.6213, 0.7015, 0.6250, 0.5980, 0.5716], requires_grad=True)]
# epoch=575, tau=1.83791, train_err = 0.115876, test_rmse=0.175465, test nrmse=0.186784, test_mae=0.10939, test nmae=0.116446
# [tensor([0.4928, 0.4937, 0.4982], requires_grad=True), tensor([0.4665, 0.4910, 0.4667, 0.4759, 0.4654], requires_grad=True), tensor([0.6259, 0.7067, 0.6287, 0.6042, 0.5741], requires_grad=True)]
# epoch=580, tau=1.84787, train_err = 0.115316, test_rmse=0.174723, test nrmse=0.185994, test_mae=0.108854, test nmae=0.115876
# [tensor([0.4963, 0.4973, 0.5017], requires_grad=True), tensor([0.4700, 0.4941, 0.4699, 0.4789, 0.4683], requires_grad=True), tensor([0.6305, 0.7118, 0.6324, 0.6104, 0.5767], requires_grad=True)]
# epoch=585, tau=1.85789, train_err = 0.114766, test_rmse=0.17399, test nrmse=0.185214, test_mae=0.108327, test nmae=0.115315
# [tensor([0.4998, 0.5008, 0.5052], requires_grad=True), tensor([0.4734, 0.4973, 0.4730, 0.4819, 0.4713], requires_grad=True), tensor([0.6351, 0.7168, 0.6361, 0.6167, 0.5791], requires_grad=True)]
# epoch=590, tau=1.86796, train_err = 0.114225, test_rmse=0.173265, test nrmse=0.184442, test_mae=0.107807, test nmae=0.114762
# [tensor([0.5033, 0.5043, 0.5086], requires_grad=True), tensor([0.4769, 0.5004, 0.4761, 0.4850, 0.4742], requires_grad=True), tensor([0.6397, 0.7217, 0.6398, 0.6228, 0.5815], requires_grad=True)]
# epoch=595, tau=1.87809, train_err = 0.113694, test_rmse=0.172548, test nrmse=0.183679, test_mae=0.107295, test nmae=0.114217
# [tensor([0.5068, 0.5078, 0.5120], requires_grad=True), tensor([0.4804, 0.5036, 0.4792, 0.4879, 0.4772], requires_grad=True), tensor([0.6443, 0.7266, 0.6435, 0.6290, 0.5839], requires_grad=True)]
# epoch=600, tau=1.88827, train_err = 0.11317, test_rmse=0.171838, test nrmse=0.182923, test_mae=0.106791, test nmae=0.11368
# [tensor([0.5103, 0.5113, 0.5154], requires_grad=True), tensor([0.4838, 0.5067, 0.4823, 0.4909, 0.4801], requires_grad=True), tensor([0.6489, 0.7314, 0.6471, 0.6352, 0.5862], requires_grad=True)]
# epoch=605, tau=1.89851, train_err = 0.112654, test_rmse=0.171135, test nrmse=0.182175, test_mae=0.106294, test nmae=0.113151
# [tensor([0.5138, 0.5148, 0.5188], requires_grad=True), tensor([0.4872, 0.5098, 0.4854, 0.4939, 0.4831], requires_grad=True), tensor([0.6535, 0.7362, 0.6508, 0.6413, 0.5885], requires_grad=True)]
# epoch=610, tau=1.90879, train_err = 0.112144, test_rmse=0.170438, test nrmse=0.181432, test_mae=0.105803, test nmae=0.112629
# [tensor([0.5173, 0.5183, 0.5222], requires_grad=True), tensor([0.4907, 0.5130, 0.4885, 0.4969, 0.4861], requires_grad=True), tensor([0.6581, 0.7408, 0.6544, 0.6474, 0.5907], requires_grad=True)]
# epoch=615, tau=1.91914, train_err = 0.111638, test_rmse=0.169745, test nrmse=0.180695, test_mae=0.105319, test nmae=0.112113
# [tensor([0.5207, 0.5218, 0.5256], requires_grad=True), tensor([0.4941, 0.5161, 0.4917, 0.4998, 0.4890], requires_grad=True), tensor([0.6627, 0.7454, 0.6581, 0.6535, 0.5929], requires_grad=True)]
# epoch=620, tau=1.92954, train_err = 0.111137, test_rmse=0.169057, test nrmse=0.179963, test_mae=0.10484, test nmae=0.111603
# [tensor([0.5242, 0.5252, 0.5290], requires_grad=True), tensor([0.4976, 0.5192, 0.4948, 0.5028, 0.4920], requires_grad=True), tensor([0.6674, 0.7499, 0.6617, 0.6596, 0.5950], requires_grad=True)]
# epoch=625, tau=1.93999, train_err = 0.110638, test_rmse=0.168373, test nrmse=0.179235, test_mae=0.104366, test nmae=0.111098
# [tensor([0.5276, 0.5287, 0.5324], requires_grad=True), tensor([0.5010, 0.5224, 0.4979, 0.5057, 0.4950], requires_grad=True), tensor([0.6720, 0.7544, 0.6654, 0.6657, 0.5971], requires_grad=True)]
# epoch=630, tau=1.9505, train_err = 0.110142, test_rmse=0.167692, test nrmse=0.17851, test_mae=0.103896, test nmae=0.110598
# [tensor([0.5311, 0.5321, 0.5357], requires_grad=True), tensor([0.5044, 0.5255, 0.5010, 0.5086, 0.4980], requires_grad=True), tensor([0.6766, 0.7587, 0.6690, 0.6718, 0.5992], requires_grad=True)]
# epoch=635, tau=1.96107, train_err = 0.109649, test_rmse=0.167014, test nrmse=0.177788, test_mae=0.103429, test nmae=0.110101
# [tensor([0.5345, 0.5355, 0.5391], requires_grad=True), tensor([0.5078, 0.5286, 0.5042, 0.5115, 0.5010], requires_grad=True), tensor([0.6812, 0.7630, 0.6727, 0.6778, 0.6013], requires_grad=True)]
# epoch=640, tau=1.97169, train_err = 0.109157, test_rmse=0.166339, test nrmse=0.17707, test_mae=0.102966, test nmae=0.109608
# [tensor([0.5379, 0.5390, 0.5424], requires_grad=True), tensor([0.5112, 0.5318, 0.5073, 0.5144, 0.5041], requires_grad=True), tensor([0.6857, 0.7673, 0.6763, 0.6838, 0.6033], requires_grad=True)]
# epoch=645, tau=1.98237, train_err = 0.108666, test_rmse=0.165667, test nrmse=0.176354, test_mae=0.102506, test nmae=0.109119
# [tensor([0.5413, 0.5424, 0.5457], requires_grad=True), tensor([0.5146, 0.5349, 0.5104, 0.5173, 0.5071], requires_grad=True), tensor([0.6903, 0.7714, 0.6799, 0.6898, 0.6053], requires_grad=True)]
# epoch=650, tau=1.99311, train_err = 0.108178, test_rmse=0.164998, test nrmse=0.175642, test_mae=0.10205, test nmae=0.108633
# [tensor([0.5447, 0.5458, 0.5490], requires_grad=True), tensor([0.5180, 0.5380, 0.5135, 0.5201, 0.5102], requires_grad=True), tensor([0.6948, 0.7755, 0.6836, 0.6958, 0.6073], requires_grad=True)]
# epoch=655, tau=2.0039, train_err = 0.107692, test_rmse=0.164332, test nrmse=0.174933, test_mae=0.101598, test nmae=0.108152
# [tensor([0.5481, 0.5492, 0.5523], requires_grad=True), tensor([0.5213, 0.5411, 0.5167, 0.5230, 0.5132], requires_grad=True), tensor([0.6993, 0.7796, 0.6872, 0.7018, 0.6093], requires_grad=True)]
# epoch=660, tau=2.01475, train_err = 0.107209, test_rmse=0.163669, test nrmse=0.174228, test_mae=0.101149, test nmae=0.107674
# [tensor([0.5515, 0.5526, 0.5556], requires_grad=True), tensor([0.5247, 0.5442, 0.5198, 0.5258, 0.5163], requires_grad=True), tensor([0.7038, 0.7836, 0.6908, 0.7078, 0.6112], requires_grad=True)]
# epoch=665, tau=2.02566, train_err = 0.106728, test_rmse=0.16301, test nrmse=0.173526, test_mae=0.100703, test nmae=0.1072
# [tensor([0.5549, 0.5560, 0.5589], requires_grad=True), tensor([0.5280, 0.5474, 0.5229, 0.5286, 0.5193], requires_grad=True), tensor([0.7083, 0.7875, 0.6945, 0.7137, 0.6132], requires_grad=True)]
# epoch=670, tau=2.03663, train_err = 0.10625, test_rmse=0.162354, test nrmse=0.172828, test_mae=0.100262, test nmae=0.10673
# [tensor([0.5582, 0.5594, 0.5621], requires_grad=True), tensor([0.5314, 0.5505, 0.5260, 0.5314, 0.5224], requires_grad=True), tensor([0.7127, 0.7914, 0.6981, 0.7197, 0.6151], requires_grad=True)]
# epoch=675, tau=2.04765, train_err = 0.105774, test_rmse=0.161702, test nrmse=0.172134, test_mae=0.099824, test nmae=0.106264
# [tensor([0.5616, 0.5627, 0.5654], requires_grad=True), tensor([0.5347, 0.5536, 0.5291, 0.5341, 0.5255], requires_grad=True), tensor([0.7171, 0.7952, 0.7017, 0.7256, 0.6170], requires_grad=True)]
# epoch=680, tau=2.05873, train_err = 0.105299, test_rmse=0.161053, test nrmse=0.171443, test_mae=0.0993896, test nmae=0.105801
# [tensor([0.5649, 0.5661, 0.5686], requires_grad=True), tensor([0.5380, 0.5567, 0.5323, 0.5369, 0.5286], requires_grad=True), tensor([0.7215, 0.7990, 0.7053, 0.7315, 0.6190], requires_grad=True)]
# epoch=685, tau=2.06987, train_err = 0.104826, test_rmse=0.160407, test nrmse=0.170755, test_mae=0.0989581, test nmae=0.105342
# [tensor([0.5683, 0.5694, 0.5719], requires_grad=True), tensor([0.5413, 0.5598, 0.5354, 0.5396, 0.5317], requires_grad=True), tensor([0.7258, 0.8028, 0.7089, 0.7374, 0.6209], requires_grad=True)]
# epoch=690, tau=2.08107, train_err = 0.104353, test_rmse=0.159764, test nrmse=0.17007, test_mae=0.0985291, test nmae=0.104885
# [tensor([0.5716, 0.5728, 0.5751], requires_grad=True), tensor([0.5445, 0.5629, 0.5385, 0.5423, 0.5348], requires_grad=True), tensor([0.7302, 0.8066, 0.7125, 0.7433, 0.6228], requires_grad=True)]
# epoch=695, tau=2.09233, train_err = 0.103879, test_rmse=0.159122, test nrmse=0.169387, test_mae=0.0981021, test nmae=0.104431
# [tensor([0.5750, 0.5761, 0.5783], requires_grad=True), tensor([0.5478, 0.5660, 0.5416, 0.5450, 0.5380], requires_grad=True), tensor([0.7345, 0.8103, 0.7162, 0.7492, 0.6247], requires_grad=True)]
# epoch=700, tau=2.10365, train_err = 0.103404, test_rmse=0.158481, test nrmse=0.168705, test_mae=0.0976764, test nmae=0.103977
# [tensor([0.5783, 0.5794, 0.5815], requires_grad=True), tensor([0.5510, 0.5690, 0.5446, 0.5477, 0.5411], requires_grad=True), tensor([0.7388, 0.8140, 0.7198, 0.7551, 0.6266], requires_grad=True)]
# epoch=705, tau=2.11503, train_err = 0.102926, test_rmse=0.157841, test nrmse=0.168024, test_mae=0.0972519, test nmae=0.103526
# [tensor([0.5816, 0.5827, 0.5847], requires_grad=True), tensor([0.5543, 0.5721, 0.5477, 0.5503, 0.5442], requires_grad=True), tensor([0.7431, 0.8177, 0.7234, 0.7610, 0.6285], requires_grad=True)]
# epoch=710, tau=2.12647, train_err = 0.102445, test_rmse=0.157202, test nrmse=0.167343, test_mae=0.0968278, test nmae=0.103074
# [tensor([0.5849, 0.5861, 0.5879], requires_grad=True), tensor([0.5575, 0.5752, 0.5508, 0.5530, 0.5474], requires_grad=True), tensor([0.7473, 0.8214, 0.7270, 0.7668, 0.6304], requires_grad=True)]
# epoch=715, tau=2.13797, train_err = 0.10196, test_rmse=0.156562, test nrmse=0.166661, test_mae=0.0964038, test nmae=0.102623
# [tensor([0.5882, 0.5894, 0.5911], requires_grad=True), tensor([0.5607, 0.5783, 0.5538, 0.5556, 0.5505], requires_grad=True), tensor([0.7516, 0.8251, 0.7306, 0.7727, 0.6322], requires_grad=True)]
# epoch=720, tau=2.14953, train_err = 0.101472, test_rmse=0.155922, test nrmse=0.16598, test_mae=0.0959797, test nmae=0.102171
# [tensor([0.5915, 0.5927, 0.5943], requires_grad=True), tensor([0.5638, 0.5813, 0.5568, 0.5582, 0.5537], requires_grad=True), tensor([0.7559, 0.8287, 0.7342, 0.7786, 0.6341], requires_grad=True)]
# epoch=725, tau=2.16115, train_err = 0.10098, test_rmse=0.155282, test nrmse=0.165299, test_mae=0.0955555, test nmae=0.10172
# [tensor([0.5948, 0.5959, 0.5974], requires_grad=True), tensor([0.5670, 0.5844, 0.5599, 0.5608, 0.5568], requires_grad=True), tensor([0.7601, 0.8324, 0.7378, 0.7844, 0.6360], requires_grad=True)]
# epoch=730, tau=2.17283, train_err = 0.100485, test_rmse=0.154642, test nrmse=0.164618, test_mae=0.0951316, test nmae=0.101268
# [tensor([0.5980, 0.5992, 0.6006], requires_grad=True), tensor([0.5701, 0.5875, 0.5629, 0.5634, 0.5600], requires_grad=True), tensor([0.7644, 0.8361, 0.7415, 0.7903, 0.6379], requires_grad=True)]
# epoch=735, tau=2.18457, train_err = 0.0999872, test_rmse=0.154002, test nrmse=0.163937, test_mae=0.094707, test nmae=0.100816
# [tensor([0.6013, 0.6025, 0.6037], requires_grad=True), tensor([0.5732, 0.5905, 0.5658, 0.5660, 0.5631], requires_grad=True), tensor([0.7687, 0.8397, 0.7451, 0.7961, 0.6398], requires_grad=True)]
# epoch=740, tau=2.19637, train_err = 0.0994852, test_rmse=0.153362, test nrmse=0.163256, test_mae=0.0942812, test nmae=0.100363
# [tensor([0.6046, 0.6058, 0.6069], requires_grad=True), tensor([0.5763, 0.5936, 0.5688, 0.5685, 0.5663], requires_grad=True), tensor([0.7730, 0.8434, 0.7487, 0.8019, 0.6417], requires_grad=True)]
# ...
# [tensor([5.2769, 5.3148, 1.3841], requires_grad=True), tensor([1.1951, 1.8599, 0.6680, 1.2962, 1.4359], requires_grad=True), tensor([2.1474, 2.3273, 1.8967, 1.8756, 1.9173], requires_grad=True)]
# epoch=9760, tau=19510.1, train_err = 0.0119228, test_rmse=0.0156273, test nrmse=0.0166354, test_mae=0.00941892, test nmae=0.0100265
# [tensor([5.2774, 5.3155, 1.3843], requires_grad=True), tensor([1.1951, 1.8598, 0.6681, 1.2962, 1.4360], requires_grad=True), tensor([2.1476, 2.3275, 1.8968, 1.8754, 1.9174], requires_grad=True)]
# epoch=9765, tau=19606.1, train_err = 0.0119251, test_rmse=0.0156287, test nrmse=0.0166369, test_mae=0.00941997, test nmae=0.0100276
# [tensor([5.2780, 5.3162, 1.3845], requires_grad=True), tensor([1.1950, 1.8597, 0.6682, 1.2962, 1.4361], requires_grad=True), tensor([2.1479, 2.3277, 1.8970, 1.8752, 1.9175], requires_grad=True)]
# epoch=9770, tau=19702.7, train_err = 0.0119273, test_rmse=0.0156301, test nrmse=0.0166384, test_mae=0.00942101, test nmae=0.0100287
# [tensor([5.2785, 5.3168, 1.3848], requires_grad=True), tensor([1.1950, 1.8597, 0.6684, 1.2961, 1.4361], requires_grad=True), tensor([2.1482, 2.3280, 1.8971, 1.8750, 1.9176], requires_grad=True)]
# epoch=9775, tau=19799.6, train_err = 0.0119296, test_rmse=0.0156316, test nrmse=0.0166399, test_mae=0.00942205, test nmae=0.0100299
# [tensor([5.2790, 5.3175, 1.3850], requires_grad=True), tensor([1.1950, 1.8596, 0.6685, 1.2961, 1.4362], requires_grad=True), tensor([2.1485, 2.3282, 1.8972, 1.8748, 1.9177], requires_grad=True)]
# epoch=9780, tau=19897.1, train_err = 0.0119318, test_rmse=0.015633, test nrmse=0.0166414, test_mae=0.00942309, test nmae=0.010031
# [tensor([5.2795, 5.3182, 1.3852], requires_grad=True), tensor([1.1949, 1.8595, 0.6686, 1.2961, 1.4362], requires_grad=True), tensor([2.1488, 2.3284, 1.8973, 1.8746, 1.9178], requires_grad=True)]
# epoch=9785, tau=19995, train_err = 0.011934, test_rmse=0.0156344, test nrmse=0.0166429, test_mae=0.00942413, test nmae=0.0100321
# [tensor([5.2800, 5.3188, 1.3855], requires_grad=True), tensor([1.1949, 1.8594, 0.6687, 1.2960, 1.4363], requires_grad=True), tensor([2.1490, 2.3287, 1.8975, 1.8744, 1.9178], requires_grad=True)]
# epoch=9790, tau=20093.5, train_err = 0.0119363, test_rmse=0.0156358, test nrmse=0.0166444, test_mae=0.00942518, test nmae=0.0100332
# [tensor([5.2805, 5.3195, 1.3857], requires_grad=True), tensor([1.1948, 1.8594, 0.6689, 1.2960, 1.4363], requires_grad=True), tensor([2.1493, 2.3289, 1.8976, 1.8742, 1.9179], requires_grad=True)]
# epoch=9795, tau=20192.4, train_err = 0.0119385, test_rmse=0.0156372, test nrmse=0.0166459, test_mae=0.00942622, test nmae=0.0100343
# [tensor([5.2810, 5.3201, 1.3859], requires_grad=True), tensor([1.1948, 1.8593, 0.6690, 1.2960, 1.4364], requires_grad=True), tensor([2.1496, 2.3291, 1.8977, 1.8740, 1.9180], requires_grad=True)]
# epoch=9800, tau=20291.8, train_err = 0.0119408, test_rmse=0.0156386, test nrmse=0.0166474, test_mae=0.00942727, test nmae=0.0100354
# [tensor([5.2815, 5.3208, 1.3862], requires_grad=True), tensor([1.1948, 1.8592, 0.6691, 1.2959, 1.4364], requires_grad=True), tensor([2.1499, 2.3294, 1.8979, 1.8738, 1.9181], requires_grad=True)]
# epoch=9805, tau=20391.6, train_err = 0.011943, test_rmse=0.01564, test nrmse=0.0166489, test_mae=0.00942832, test nmae=0.0100365
# [tensor([5.2820, 5.3214, 1.3864], requires_grad=True), tensor([1.1947, 1.8591, 0.6692, 1.2959, 1.4365], requires_grad=True), tensor([2.1502, 2.3296, 1.8980, 1.8736, 1.9182], requires_grad=True)]
# epoch=9810, tau=20492, train_err = 0.0119452, test_rmse=0.0156414, test nrmse=0.0166504, test_mae=0.00942937, test nmae=0.0100376
# [tensor([5.2825, 5.3220, 1.3866], requires_grad=True), tensor([1.1947, 1.8591, 0.6694, 1.2959, 1.4365], requires_grad=True), tensor([2.1505, 2.3298, 1.8981, 1.8734, 1.9183], requires_grad=True)]
# epoch=9815, tau=20592.8, train_err = 0.0119475, test_rmse=0.0156428, test nrmse=0.0166519, test_mae=0.00943041, test nmae=0.0100388
# [tensor([5.2830, 5.3227, 1.3869], requires_grad=True), tensor([1.1946, 1.8590, 0.6695, 1.2958, 1.4366], requires_grad=True), tensor([2.1507, 2.3301, 1.8982, 1.8733, 1.9184], requires_grad=True)]
# epoch=9820, tau=20694.2, train_err = 0.0119497, test_rmse=0.0156442, test nrmse=0.0166534, test_mae=0.00943146, test nmae=0.0100399
# [tensor([5.2835, 5.3233, 1.3871], requires_grad=True), tensor([1.1946, 1.8589, 0.6696, 1.2958, 1.4367], requires_grad=True), tensor([2.1510, 2.3303, 1.8984, 1.8731, 1.9185], requires_grad=True)]
# epoch=9825, tau=20796, train_err = 0.0119519, test_rmse=0.0156456, test nrmse=0.0166549, test_mae=0.00943251, test nmae=0.010041
# [tensor([5.2840, 5.3239, 1.3873], requires_grad=True), tensor([1.1945, 1.8588, 0.6698, 1.2958, 1.4367], requires_grad=True), tensor([2.1513, 2.3306, 1.8985, 1.8729, 1.9186], requires_grad=True)]
# epoch=9830, tau=20898.4, train_err = 0.0119542, test_rmse=0.015647, test nrmse=0.0166564, test_mae=0.00943356, test nmae=0.0100421
# [tensor([5.2845, 5.3245, 1.3876], requires_grad=True), tensor([1.1945, 1.8588, 0.6699, 1.2957, 1.4368], requires_grad=True), tensor([2.1516, 2.3308, 1.8986, 1.8727, 1.9187], requires_grad=True)]
# epoch=9835, tau=21001.2, train_err = 0.0119564, test_rmse=0.0156484, test nrmse=0.0166579, test_mae=0.00943461, test nmae=0.0100432
# [tensor([5.2849, 5.3251, 1.3878], requires_grad=True), tensor([1.1945, 1.8587, 0.6700, 1.2957, 1.4368], requires_grad=True), tensor([2.1519, 2.3311, 1.8987, 1.8726, 1.9189], requires_grad=True)]
# epoch=9840, tau=21104.6, train_err = 0.0119586, test_rmse=0.0156498, test nrmse=0.0166594, test_mae=0.00943566, test nmae=0.0100443
# [tensor([5.2854, 5.3257, 1.3880], requires_grad=True), tensor([1.1944, 1.8586, 0.6702, 1.2957, 1.4369], requires_grad=True), tensor([2.1522, 2.3313, 1.8989, 1.8724, 1.9190], requires_grad=True)]
# epoch=9845, tau=21208.4, train_err = 0.0119608, test_rmse=0.0156512, test nrmse=0.0166609, test_mae=0.00943671, test nmae=0.0100455
# [tensor([5.2859, 5.3263, 1.3883], requires_grad=True), tensor([1.1944, 1.8585, 0.6703, 1.2956, 1.4369], requires_grad=True), tensor([2.1525, 2.3316, 1.8990, 1.8722, 1.9191], requires_grad=True)]
# epoch=9850, tau=21312.8, train_err = 0.011963, test_rmse=0.0156526, test nrmse=0.0166623, test_mae=0.00943776, test nmae=0.0100466
# [tensor([5.2863, 5.3269, 1.3885], requires_grad=True), tensor([1.1943, 1.8585, 0.6704, 1.2956, 1.4370], requires_grad=True), tensor([2.1528, 2.3318, 1.8992, 1.8720, 1.9192], requires_grad=True)]
# epoch=9855, tau=21417.6, train_err = 0.0119653, test_rmse=0.015654, test nrmse=0.0166638, test_mae=0.00943882, test nmae=0.0100477
# [tensor([5.2868, 5.3275, 1.3887], requires_grad=True), tensor([1.1943, 1.8584, 0.6706, 1.2956, 1.4371], requires_grad=True), tensor([2.1531, 2.3320, 1.8993, 1.8719, 1.9193], requires_grad=True)]
# epoch=9860, tau=21523, train_err = 0.0119675, test_rmse=0.0156554, test nrmse=0.0166653, test_mae=0.00943988, test nmae=0.0100488
# [tensor([5.2873, 5.3281, 1.3890], requires_grad=True), tensor([1.1942, 1.8583, 0.6707, 1.2955, 1.4371], requires_grad=True), tensor([2.1534, 2.3323, 1.8994, 1.8717, 1.9194], requires_grad=True)]
# epoch=9865, tau=21628.9, train_err = 0.0119697, test_rmse=0.0156568, test nrmse=0.0166668, test_mae=0.00944093, test nmae=0.01005
# [tensor([5.2877, 5.3287, 1.3892], requires_grad=True), tensor([1.1942, 1.8582, 0.6708, 1.2955, 1.4372], requires_grad=True), tensor([2.1537, 2.3325, 1.8996, 1.8715, 1.9195], requires_grad=True)]
# epoch=9870, tau=21735.3, train_err = 0.0119719, test_rmse=0.0156582, test nrmse=0.0166683, test_mae=0.00944199, test nmae=0.0100511
# [tensor([5.2882, 5.3293, 1.3894], requires_grad=True), tensor([1.1941, 1.8582, 0.6710, 1.2955, 1.4372], requires_grad=True), tensor([2.1540, 2.3328, 1.8997, 1.8713, 1.9196], requires_grad=True)]
# epoch=9875, tau=21842.3, train_err = 0.0119741, test_rmse=0.0156596, test nrmse=0.0166697, test_mae=0.00944304, test nmae=0.0100522
# [tensor([5.2886, 5.3299, 1.3897], requires_grad=True), tensor([1.1941, 1.8581, 0.6711, 1.2955, 1.4373], requires_grad=True), tensor([2.1543, 2.3331, 1.8998, 1.8712, 1.9197], requires_grad=True)]
# epoch=9880, tau=21949.7, train_err = 0.0119763, test_rmse=0.0156609, test nrmse=0.0166712, test_mae=0.00944409, test nmae=0.0100533
# [tensor([5.2891, 5.3304, 1.3899], requires_grad=True), tensor([1.1940, 1.8580, 0.6713, 1.2954, 1.4374], requires_grad=True), tensor([2.1546, 2.3333, 1.9000, 1.8710, 1.9199], requires_grad=True)]
# epoch=9885, tau=22057.7, train_err = 0.0119785, test_rmse=0.0156623, test nrmse=0.0166727, test_mae=0.00944515, test nmae=0.0100544
# [tensor([5.2895, 5.3310, 1.3901], requires_grad=True), tensor([1.1940, 1.8580, 0.6714, 1.2954, 1.4374], requires_grad=True), tensor([2.1549, 2.3336, 1.9001, 1.8708, 1.9200], requires_grad=True)]
# epoch=9890, tau=22166.2, train_err = 0.0119807, test_rmse=0.0156637, test nrmse=0.0166741, test_mae=0.0094462, test nmae=0.0100556
# [tensor([5.2899, 5.3316, 1.3904], requires_grad=True), tensor([1.1939, 1.8579, 0.6715, 1.2954, 1.4375], requires_grad=True), tensor([2.1552, 2.3338, 1.9002, 1.8707, 1.9201], requires_grad=True)]
# epoch=9895, tau=22275.3, train_err = 0.0119829, test_rmse=0.0156651, test nrmse=0.0166756, test_mae=0.00944726, test nmae=0.0100567
# [tensor([5.2904, 5.3321, 1.3906], requires_grad=True), tensor([1.1939, 1.8578, 0.6717, 1.2953, 1.4376], requires_grad=True), tensor([2.1555, 2.3341, 1.9004, 1.8705, 1.9202], requires_grad=True)]
# epoch=9900, tau=22384.9, train_err = 0.0119851, test_rmse=0.0156664, test nrmse=0.0166771, test_mae=0.00944831, test nmae=0.0100578
# [tensor([5.2908, 5.3327, 1.3908], requires_grad=True), tensor([1.1938, 1.8578, 0.6718, 1.2953, 1.4376], requires_grad=True), tensor([2.1559, 2.3343, 1.9005, 1.8703, 1.9203], requires_grad=True)]
# epoch=9905, tau=22495, train_err = 0.0119873, test_rmse=0.0156678, test nrmse=0.0166785, test_mae=0.00944936, test nmae=0.0100589
# [tensor([5.2912, 5.3332, 1.3911], requires_grad=True), tensor([1.1938, 1.8577, 0.6720, 1.2953, 1.4377], requires_grad=True), tensor([2.1562, 2.3346, 1.9007, 1.8702, 1.9205], requires_grad=True)]
# epoch=9910, tau=22605.6, train_err = 0.0119895, test_rmse=0.0156692, test nrmse=0.01668, test_mae=0.00945041, test nmae=0.0100601
# [tensor([5.2916, 5.3338, 1.3913], requires_grad=True), tensor([1.1937, 1.8576, 0.6721, 1.2952, 1.4377], requires_grad=True), tensor([2.1565, 2.3349, 1.9008, 1.8700, 1.9206], requires_grad=True)]
# epoch=9915, tau=22716.8, train_err = 0.0119917, test_rmse=0.0156706, test nrmse=0.0166814, test_mae=0.00945147, test nmae=0.0100612
# [tensor([5.2921, 5.3343, 1.3915], requires_grad=True), tensor([1.1937, 1.8575, 0.6722, 1.2952, 1.4378], requires_grad=True), tensor([2.1568, 2.3351, 1.9009, 1.8699, 1.9207], requires_grad=True)]
# epoch=9920, tau=22828.6, train_err = 0.0119939, test_rmse=0.0156719, test nrmse=0.0166829, test_mae=0.00945252, test nmae=0.0100623
# [tensor([5.2925, 5.3349, 1.3918], requires_grad=True), tensor([1.1936, 1.8575, 0.6724, 1.2952, 1.4379], requires_grad=True), tensor([2.1571, 2.3354, 1.9011, 1.8697, 1.9208], requires_grad=True)]
# epoch=9925, tau=22940.9, train_err = 0.0119961, test_rmse=0.0156733, test nrmse=0.0166844, test_mae=0.00945358, test nmae=0.0100634
# [tensor([5.2929, 5.3354, 1.3920], requires_grad=True), tensor([1.1936, 1.8574, 0.6725, 1.2951, 1.4379], requires_grad=True), tensor([2.1574, 2.3357, 1.9012, 1.8696, 1.9210], requires_grad=True)]
# epoch=9930, tau=23053.7, train_err = 0.0119983, test_rmse=0.0156747, test nrmse=0.0166858, test_mae=0.00945464, test nmae=0.0100645
# [tensor([5.2933, 5.3359, 1.3922], requires_grad=True), tensor([1.1935, 1.8573, 0.6727, 1.2951, 1.4380], requires_grad=True), tensor([2.1577, 2.3359, 1.9014, 1.8694, 1.9211], requires_grad=True)]
# epoch=9935, tau=23167.1, train_err = 0.0120005, test_rmse=0.015676, test nrmse=0.0166873, test_mae=0.00945569, test nmae=0.0100657
# [tensor([5.2937, 5.3365, 1.3925], requires_grad=True), tensor([1.1934, 1.8573, 0.6728, 1.2951, 1.4381], requires_grad=True), tensor([2.1581, 2.3362, 1.9015, 1.8693, 1.9212], requires_grad=True)]
# epoch=9940, tau=23281, train_err = 0.0120026, test_rmse=0.0156774, test nrmse=0.0166887, test_mae=0.00945675, test nmae=0.0100668
# [tensor([5.2941, 5.3370, 1.3927], requires_grad=True), tensor([1.1934, 1.8572, 0.6730, 1.2950, 1.4381], requires_grad=True), tensor([2.1584, 2.3365, 1.9016, 1.8691, 1.9214], requires_grad=True)]
# epoch=9945, tau=23395.5, train_err = 0.0120048, test_rmse=0.0156787, test nrmse=0.0166902, test_mae=0.0094578, test nmae=0.0100679
# [tensor([5.2945, 5.3375, 1.3929], requires_grad=True), tensor([1.1933, 1.8572, 0.6731, 1.2950, 1.4382], requires_grad=True), tensor([2.1587, 2.3368, 1.9018, 1.8690, 1.9215], requires_grad=True)]
# epoch=9950, tau=23510.6, train_err = 0.012007, test_rmse=0.0156801, test nrmse=0.0166916, test_mae=0.00945886, test nmae=0.010069
# [tensor([5.2949, 5.3380, 1.3932], requires_grad=True), tensor([1.1933, 1.8571, 0.6733, 1.2950, 1.4383], requires_grad=True), tensor([2.1590, 2.3370, 1.9019, 1.8688, 1.9216], requires_grad=True)]
# epoch=9955, tau=23626.2, train_err = 0.0120092, test_rmse=0.0156814, test nrmse=0.016693, test_mae=0.00945991, test nmae=0.0100702
# [tensor([5.2953, 5.3386, 1.3934], requires_grad=True), tensor([1.1932, 1.8570, 0.6734, 1.2950, 1.4383], requires_grad=True), tensor([2.1593, 2.3373, 1.9021, 1.8687, 1.9218], requires_grad=True)]
# epoch=9960, tau=23742.4, train_err = 0.0120113, test_rmse=0.0156828, test nrmse=0.0166945, test_mae=0.00946097, test nmae=0.0100713
# [tensor([5.2957, 5.3391, 1.3936], requires_grad=True), tensor([1.1932, 1.8570, 0.6736, 1.2949, 1.4384], requires_grad=True), tensor([2.1597, 2.3376, 1.9022, 1.8686, 1.9219], requires_grad=True)]
# epoch=9965, tau=23859.1, train_err = 0.0120135, test_rmse=0.0156841, test nrmse=0.0166959, test_mae=0.00946203, test nmae=0.0100724
# [tensor([5.2961, 5.3396, 1.3939], requires_grad=True), tensor([1.1931, 1.8569, 0.6737, 1.2949, 1.4385], requires_grad=True), tensor([2.1600, 2.3379, 1.9023, 1.8684, 1.9221], requires_grad=True)]
# epoch=9970, tau=23976.4, train_err = 0.0120157, test_rmse=0.0156855, test nrmse=0.0166974, test_mae=0.00946308, test nmae=0.0100735
# [tensor([5.2965, 5.3401, 1.3941], requires_grad=True), tensor([1.1930, 1.8568, 0.6739, 1.2949, 1.4386], requires_grad=True), tensor([2.1603, 2.3381, 1.9025, 1.8683, 1.9222], requires_grad=True)]
# epoch=9975, tau=24094.3, train_err = 0.0120178, test_rmse=0.0156868, test nrmse=0.0166988, test_mae=0.00946413, test nmae=0.0100747
# [tensor([5.2969, 5.3406, 1.3943], requires_grad=True), tensor([1.1930, 1.8568, 0.6740, 1.2948, 1.4386], requires_grad=True), tensor([2.1606, 2.3384, 1.9026, 1.8681, 1.9223], requires_grad=True)]
# epoch=9980, tau=24212.8, train_err = 0.01202, test_rmse=0.0156882, test nrmse=0.0167002, test_mae=0.00946518, test nmae=0.0100758
# [tensor([5.2973, 5.3411, 1.3945], requires_grad=True), tensor([1.1929, 1.8567, 0.6742, 1.2948, 1.4387], requires_grad=True), tensor([2.1610, 2.3387, 1.9028, 1.8680, 1.9225], requires_grad=True)]
# epoch=9985, tau=24331.9, train_err = 0.0120221, test_rmse=0.0156895, test nrmse=0.0167016, test_mae=0.00946624, test nmae=0.0100769
# [tensor([5.2976, 5.3416, 1.3948], requires_grad=True), tensor([1.1929, 1.8566, 0.6743, 1.2948, 1.4388], requires_grad=True), tensor([2.1613, 2.3390, 1.9029, 1.8679, 1.9226], requires_grad=True)]
# epoch=9990, tau=24451.5, train_err = 0.0120243, test_rmse=0.0156909, test nrmse=0.0167031, test_mae=0.00946728, test nmae=0.010078
# [tensor([5.2980, 5.3421, 1.3950], requires_grad=True), tensor([1.1928, 1.8566, 0.6745, 1.2947, 1.4388], requires_grad=True), tensor([2.1616, 2.3393, 1.9031, 1.8677, 1.9228], requires_grad=True)]
# epoch=9995, tau=24571.7, train_err = 0.0120264, test_rmse=0.0156922, test nrmse=0.0167045, test_mae=0.00946834, test nmae=0.0100791
# [tensor([5.2983, 5.3425, 1.3952], requires_grad=True), tensor([1.1927, 1.8565, 0.6746, 1.2947, 1.4389], requires_grad=True), tensor([2.1619, 2.3395, 1.9032, 1.8676, 1.9229], requires_grad=True)]
# epoch=10000, tau=24668.3, train_err = 0.0120281, test_rmse=0.0156933, test nrmse=0.0167056, test_mae=0.00946918, test nmae=0.01008

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.plot(epochs, test_rmse, label='RMSE')
plt.plot(epochs, test_nrmse, label='NRMSE')
plt.plot(epochs, test_mae, label='MAE')
plt.plot(epochs, test_nmae, label='NMAE')

plt.xlabel('Epochs')
plt.ylabel('Test Score')
plt.title('Test Scores over Epochs')
plt.legend()

plt.show()

# %%
from pdf2image import convert_from_path
from IPython.display import Image, display
pdf_path = "__figs__/errors_Heat_HOGP.pdf"

# Convert the PDF to images
images = convert_from_path(pdf_path)

images[0].save("__figs__/errors_Heat_HOGP.png", 'PNG')

display(Image(filename='__figs__/errors_Heat_HOGP.png'))

# %%
from pdf2image import convert_from_path
from IPython.display import Image, display
pdf_path = "__figs__/errors_Poisson_HOGP.pdf"
images = convert_from_path(pdf_path)

images[0].save("__figs__/errors_Poisson_HOGP.png", 'PNG')

display(Image(filename='__figs__/errors_Poisson_HOGP.png'))
